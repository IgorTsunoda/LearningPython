# %%
# Soma
4 + 4
# Out:
# 8

# %%
# Subtração
4 - 3
# Out:
# 1

# %%
# Multiplicação
3 * 3
# Out:
# 9

# %%
# Divisão
4 / 2
# Out:
# 2.0

# %%
# Potencia
4 ** 2
# Out:
# 16

# %%
# Módulo
10 % 3
# Out:
# 1

# %% [markdown]
# Função Type

# %%
type(5)
# Out:
# int

# %%
type(5.0)
# Out:
# float

# %%
type("estou aprendendo python")
# Out:
# str

# %% [markdown]
# Operações com números float

# %%
3.1 + 6.4
# Out:
# 9.5

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 + 4
# Out:
# 8

# %%
# Resultado é um número float
4 / 2
# Out:
# 2.0

# %%
# Resultado é um número inteiro
4 // 2
# Out:
# 2

# %%
4 / 3.0
# Out:
# 1.3333333333333333

# %%
4 // 3.0
# Out:
# 1.0

# %% [markdown]
# Conversões

# %%
float(9)
# Out:
# 9.0

# %%
int(6.0)
# Out:
# 6

# %%
int(6.5)
# Out:
# 6

# %%
int(6.6)
# Out:
# 6

# %% [markdown]
# Hexadecimal e Binario

# %%
hex(289)
# Out:
# '0x121'

# %%
hex(367)
# Out:
# '0x16f'

# %%
bin(289)
# Out:
# '0b100100001'

# %%
bin(367)
# Out:
# '0b101101111'

# %% [markdown]
# Funções abs, round e pow

# %%
# Retorna um valor absoluto
abs(8)

# %%
# Retorna um valor absoluto
abs(-8)

# %%
round(3.020040657,2)
